# %%
from nba_api.stats.static import teams
from nba_api.stats.endpoints import teamdetails

nba_teams = teams.get_teams()

team_id = 1610612744
team_info = teamdetails.TeamDetails(team_id=team_id)

print(team_info.team_background.get_data_frame().columns.tolist())
# Out:
# ['TEAM_ID', 'ABBREVIATION', 'NICKNAME', 'YEARFOUNDED', 'CITY', 'ARENA', 'ARENACAPACITY', 'OWNER', 'GENERALMANAGER', 'HEADCOACH', 'DLEAGUEAFFILIATION']
