# %%
import sys
from pathlib import Path

project_root = Path.cwd().parent
sys.path.insert(0, str(project_root))

from src.core.data_fetcher import NBADataFetcher

fetcher = NBADataFetcher()
team_id = 1610612744

roster_df = fetcher.get_team_roster(team_id)

roster_df.columns
# Out:
# Index(['TeamID', 'SEASON', 'LeagueID', 'PLAYER', 'NICKNAME', 'PLAYER_SLUG',
#        'NUM', 'POSITION', 'HEIGHT', 'WEIGHT', 'BIRTH_DATE', 'AGE', 'EXP',
#        'SCHOOL', 'PLAYER_ID', 'HOW_ACQUIRED'],
#       dtype='str')
